# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import json
import yaml

# %%
data = []

with open('/content/gdrive/MyDrive/colab/web3_question.yml', 'r') as file:
  Lines = file.readlines()
  count = 0
  question = ""
  for line in Lines:
    count += 1
    if count >= 4:
      if count%2 == 0:
        question = line.strip("- \n")
      else:
        answer = line.strip("- \n")
        data.append([question, answer])

data
# Out:
# [['What is Web3?',
#   'Web3 utilizes different technologies such as blockchain, machine learning, IoT and big data to enable websites and applications to manage data just like humans. The primary goal of web3 revolves around the creation of a more transparent, independent and smart internet. One of the biggest highlights in web3.0 examples is the emphasis on decentralization which would prevent centralized applications from interfering with user data.'],
#  ['What is decentralization?',
# ...

# %%
convos = data

convos[0]
# Out:
# ['What is Web3?',
#  'Web3 utilizes different technologies such as blockchain, machine learning, IoT and big data to enable websites and applications to manage data just like humans. The primary goal of web3 revolves around the creation of a more transparent, independent and smart internet. One of the biggest highlights in web3.0 examples is the emphasis on decentralization which would prevent centralized applications from interfering with user data.']

# %%
output = []

# %%
for convo in convos:
  completion = ''
  for i, dialog in enumerate(convo):
    if i == 0:
      prompt = dialog
      # p_encode = prompt.encode("ascii", "ignore")
      # prompt = p_encode.decode()
      prompt = prompt.replace("\xa0", " ")
      # print('prompt:',prompt)
    else:
      completion += " " + dialog
      # c_encode = completion.encode("ascii", "ignore")
      # completion = c_encode.decode()
      completion = completion.replace("\xa0", " ")
  completion = completion.strip()
  line = {'prompt': prompt, 'completion': " " + completion + "\n"}
  # print(line)
  output.append(line)
    
print(output)
# Out:
# [{'prompt': 'What is Web3?', 'completion': ' Web3 utilizes different technologies such as blockchain, machine learning, IoT and big data to enable websites and applications to manage data just like humans. The primary goal of web3 revolves around the creation of a more transparent, independent and smart internet. One of the biggest highlights in web3.0 examples is the emphasis on decentralization which would prevent centralized applications from interfering with user data.\n'}, {'prompt': 'What is decentralization?', 'completion': ' Decentralization is the process of distributing power and authority among all participants in a network. In the case of web3, decentralization focuses on transferring the authority over data management away from centralized tech giants such as Google and Facebook. The most common blockchain interview questions related to web3 focus on decentralization and how it helps in creating a distributed model for user data storage and management. Decentralization o
# ...

# %%
from google.colab import files

# %%
with open('web3.jsonl', 'w') as outfile:
        for i in output:
            json.dump(i, outfile)
            outfile.write('\n')


files.download('web3.jsonl')

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 KB 1.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai: filename=openai-0.26.5-py3-none-any.whl size=67620 sha256=c21c3893a33adf8b254faccf95d63cfae0e2d2c30085bddba7487c9c5dc7735d
#   Stored in directory: /root/.cache/pip/wheels/a7/47/99/8273a59fbd59c303e8ff175416d5c1c9c03a2e83ebf7525a99
# Successfully built openai
# ...

# %%
# !openai tools fine_tunes.prepare_data -f '/content/gdrive/MyDrive/colab/web3.jsonl'
# Out:
# Analyzing...
#
# - Your file contains 199 prompt-completion pairs
# - Your data does not contain a common separator at the end of your prompts. Having a separator string appended to the end of the prompt makes it clearer to the fine-tuned model where the completion should begin. See https://beta.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more detail and examples. If you intend to do open-ended generation, then you should leave the prompts empty
# - All completions end with suffix `\n`
#
# Based on the analysis we will perform the following actions:
# - [Recommended] Add a suffix separator ` ->` to all prompts [Y/n]: Y
#
#
# Your data will be written to a new JSONL file. Proceed [Y/n]: Y
#
# Wrote modified file to `/content/gdrive/MyDrive/colab/web3_prepared (1).jsonl`
# Feel free to take a look!
#
# Now use that file when fine-tuning:
# > openai api fine_tunes.create -t "/content/gdrive/MyDrive/colab/web3_prepared (1).jsonl"
#
# ...

# %%
import os
import openai

# %%
os.environ['OPENAI_API_KEY'] = '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'

# %%
# !openai api fine_tunes.create -t "/content/gdrive/MyDrive/colab/web3_prepared.jsonl" -m curie
# Out:
# Upload progress: 100% 9.75k/9.75k [00:00<00:00, 11.9Mit/s]
# Uploaded file from /content/gdrive/MyDrive/colab/web3.jsonl: file-Mpg0YOtdGmaoD66PL9SJpQPv
# Created fine-tune: ft-Suqqm9PDTksefUeZMLzu9Tdc
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2023-02-12 04:01:47] Created fine-tune: ft-Suqqm9PDTksefUeZMLzu9Tdc
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-Suqqm9PDTksefUeZMLzu9Tdc

# %%
# !openai api fine_tunes.create -t "/content/gdrive/MyDrive/colab/web3_prepared.jsonl" -m davinci
# Out:
# Upload progress: 100% 198k/198k [00:00<00:00, 317Mit/s]
# Uploaded file from /content/gdrive/MyDrive/colab/web3_prepared.jsonl: file-sduIf0UNO9Jb39WPc6mtJfmP
# Created fine-tune: ft-fbAXEsCDqwQ2kFvQxp6RiiwB
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2023-02-16 08:27:25] Created fine-tune: ft-fbAXEsCDqwQ2kFvQxp6RiiwB
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-fbAXEsCDqwQ2kFvQxp6RiiwB

# %%
# !openai api fine_tunes.follow -i ft-fbAXEsCDqwQ2kFvQxp6RiiwB
# Out:
# [2023-02-16 08:27:25] Created fine-tune: ft-fbAXEsCDqwQ2kFvQxp6RiiwB
# [2023-02-16 08:35:13] Fine-tune costs $4.79
# [2023-02-16 08:35:13] Fine-tune enqueued
# [2023-02-16 08:39:43] Fine-tune is in the queue. Queue number: 31
# [2023-02-16 08:39:59] Fine-tune is in the queue. Queue number: 30
# [2023-02-16 08:40:02] Fine-tune is in the queue. Queue number: 29
# [2023-02-16 08:40:38] Fine-tune is in the queue. Queue number: 28
# [2023-02-16 08:43:17] Fine-tune is in the queue. Queue number: 27
# [2023-02-16 08:43:41] Fine-tune is in the queue. Queue number: 26
# [2023-02-16 08:46:10] Fine-tune is in the queue. Queue number: 25
# [2023-02-16 08:48:10] Fine-tune is in the queue. Queue number: 24
# [2023-02-16 08:50:52] Fine-tune is in the queue. Queue number: 23
# [2023-02-16 08:53:45] Fine-tune is in the queue. Queue number: 22
# [2023-02-16 08:56:11] Fine-tune is in the queue. Queue number: 21
# [2023-02-16 08:56:26] Fine-tune is in the queue. Queue number: 20
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "Is DeFi relevant for web3?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Developers across the globe are working on web3 DApps. However, before building a web3 DApp, it\u2019s important to identify the role of decentralized finance in web3. DeFi creates new opportunities for web3 development. As an example, DeFi could play an important role in improving the security of web3 applications."
#     }
#   ],
#   "created": 1676566538,
#   "id": "cmpl-6kbpieWkLQhTxaBjhWrUlkBNY08pm",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 68,
#     "prompt_tokens": 8,
#     "total_tokens": 76
#   }
# }

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "what is the ethereum merge?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " The Ethereum Merge program is an important feature of the Ethereum network. It consists of a series of hard forks that update the protocol and add new features to the Ethereum network. Each version of the merge has its own name. The first Ethereum Merge upgrade is called Frontier and was launched in July 2015. Other names were the February 14 date of the initiation of the transition to the canonical chain, the next version was Life, and the latest is Istanbul. At the same time, it does not affect the version number of the protocol. This is because this update is not primarily a hard fork, but rather a soft fork."
#     }
#   ],
#   "created": 1676566544,
#   "id": "cmpl-6kbpoSbSqveoXxUG9bD56RYzAZWTI",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 123,
#     "prompt_tokens": 7,
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "what is Tether (USDT)?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Tether (USDT) provides a way to store and transact with fiat-pegged stablecoins in the world\u2019s largest blockchain ecosystem. The USDT token can be redeemed for one U.S. dollar and held in reserves by Tether, a leading blockchain payment services provider (BPSP). The project aims to act as a bridge between cryptocurrency and traditional finance thanks to its role in bridging the technological divide that exists between the two. Many of the advantages of blockchain technology such as transparency, decentralization and efficiency are not currently present when it comes to holding and using traditional fiat money. USDT seeks to rectify this."
#     }
#   ],
#   "created": 1676566609,
#   "id": "cmpl-6kbqrxrlddXzn5zjPvnPLWkS6JDJ4",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
#   "usage": {
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What makes XRPL unique?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " A globally-accessible scalable cross-chain protocol, with support for every EVM-compatible chain. Notably, while other cross-chain solutions rely on centralized custody, XRPL is based on multisig smart contracts. The governance process is more decentralized than most projects, with on-chain mechanisms in place to prevent unscheduled updates."
#     }
#   ],
#   "created": 1676566630,
#   "id": "cmpl-6kbrC3c8gVaAQREyHyt8GVHqhUF26",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 69,
#     "prompt_tokens": 7,
#     "total_tokens": 76
#   }
# }

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What is dogecoin?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Dogecoin is a cryptocurrency based on Litecoin, featuring a Shiba Inu from the Doge web comic as its mascot and a tongue-in-cheek reference in its name. As of January 2017, it has a market capitalization of $20 million and maintains a daily trading volume of about $2 million. The currency first appeared online as a joke, but later gained popularity and a community of users has been building up around it. The community includes a philanthropic arm that takes donations to fund causes such as sending the Winter Olympics athletes to the Sochi games, and contributes funds to other charities such as Save the Children, Water.org and the Jamaican bobsled team for the Sochi Olympics."
#     }
#   ],
#   "created": 1676566638,
#   "id": "cmpl-6kbrKjv5Kal9eRfqIBPc5u917zAqc",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "Who is Justin Sun?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Justin Sun is a businessman and cryptocurrency enthusiast born in China and now based in the U.S. In 2014, Sun graduated from Peking University with a BA in Economics and went on to study at the University of Oxford, obtaining an MSc in Finance in 2016. That same year, he worked as an Associate at Ripple. After the launch of Tron, Sun has become one of the most prominent figures in the crypto industry. He has spoken at numerous blockchain events and even appeared on CNBC\u2019s \u201cCrypto Trader.\u201d"
#     }
#   ],
#   "created": 1676566668,
#   "id": "cmpl-6kbroPNzvD4fCCeZgGiRiIj5LZMAD",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 110,
#     "prompt_tokens": 5,
#     "total_tokens": 115
#   }
# }

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What is Avalanche (AVAX)?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What is Ethereum 2.0?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Ethereum 2.0 is a new version of the Ethereum protocol that has been in development since 2014. The focus of the upgrade is to address the scalability issues facing the original version of the blockchain by introducing new technologies such as Sharding, Layer 2 and POA on the main network. Sharding, for example, aims to increase transaction capacity by separating the process of checking and validating transactions into random partitions known as shards. Layer 2 tackles the scalability issue by moving parts of the protocol\u2019s operations onto other networks, thereby reducing the resource requirements of the Ethereum mainnet. Ethereum 2.0 is also set to introduce smart contract interoperability and provide a foundation for the introduction of powerful off-chain projects like the Raiden Network and Plasma."
#     }
#   ],
#   "created": 1676566716,
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What is BNB?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " By 2021, Binance intends to be the largest decentralized exchange by trading volume, so it's important to understand how BNB fits into that goal. The idea behind BNB is to provide a way for users to offset the higher fees associated with trading on the platform with discounted fees. In return for depositing BNB, users receive a discount on their trading and withdrawal fees. In 2018, for example, users could get a 50% discount on their fees by holding just a fraction of one BNB coin. There are other perks as well for holders of BNB, such as getting first crack at limited-release coins before any other cryptocurrency and special privileges for voting in governance proposals."
#     }
#   ],
#   "created": 1676566705,
#   "id": "cmpl-6kbsPdRfuSDnGALGfEuZBWM2oMPtR",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What makes BNB unique?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " The Binance protocol is similar to that of other blockchain platforms. However, the most obvious difference between Binance and other blockchains is that the Binance chain provides alternative treatment to the Ethereum network by hosting alternatives to decentralized exchange protocols, such as Swap.io, Uniswap, EvXY, and EOT. Furthermore, the Binance chain supports decentralized finance applications such as Margin Trading, Margin Funding, and Lending with Initial Coin Offerings (ICOs) alongside supporting basic payments and transfers. The BNB token arose as a utility for holding different fees on the platform, along with operating as a governance tool in decision-making processes on the Binance Chain, as well as providing voting rights for users on Binance.com."
#     }
#   ],
#   "created": 1676566726,
#   "id": "cmpl-6kbskTJ5cwPMUnvfjO9SxIOAbHViR",
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What is Aleo?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Aleo is a decentralized application (dapp) layer that powers the next generation of blockchain applications."
#     }
#   ],
#   "created": 1676566787,
#   "id": "cmpl-6kbtj1l8ATY11fGMADmuslZLbmOVU",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 20,
#     "prompt_tokens": 5,
#     "total_tokens": 25
#   }
# }

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What is DeFi Lending?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " A DeFi lending protocol enables lenders to fund borrowers with cryptocurrencies. Borrowers can use the loan to raise capital by liquidating their crypto holdings, trade on a decentralized exchange, or make use of the loan to diversify their portfolio. DeFi lending protocols are inspired by decentralized finance (DeF), which seeks to empower individuals to control their own funds without relying on centralized financial intermediaries like banks and credit card companies."
#     }
#   ],
#   "created": 1676566829,
#   "id": "cmpl-6kbuPBAoLSwHB98hbyfSMNYRv7pf3",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 85,
#     "prompt_tokens": 7,
#     "total_tokens": 92
#   }
# }

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = "What is a stableswap?"

response = openai.Completion.create(
                model="davinci:ft-personal-2023-02-16-09-27-27",
                prompt=query,
                temperature=0.89,
                max_tokens=162,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0.6,
                stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Stableswaps happen all the time in crypto. Typically they\u2019ll occur when there is a development update coming, or when the team is bootstrapping the network. In simple terms, stableswaps are swaps done on chain. A project would perform much of the swap mechanism manually, but it is made much more difficult by the fact that protocols use different coin structures \u2014 some are pegged, others are paired."
#     }
#   ],
#   "created": 1676566877,
#   "id": "cmpl-6kbvBDqfKInm4EelceS3KSEJe4QAf",
#   "model": "davinci:ft-personal-2023-02-16-09-27-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 86,
#     "prompt_tokens": 8,
#     "total_tokens": 94
#   }
# }
